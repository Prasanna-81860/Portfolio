# %% [markdown]
# <a href="https://colab.research.google.com/github/Prasanna-81860/Portfolio/blob/main/Time_series_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv("/content/firstdataanaystproj.csv",parse_dates=['Date'])
data
# Out:
#            Date   Open   High    Low  Close    Volume  Name
# 0    2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 1    2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2    2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 3    2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 4    2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA
# ...         ...    ...    ...    ...    ...       ...   ...
# 3014 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 3015 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 3016 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 3017 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 3018 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 7 columns]

# %%
data.head()
# Out:
#         Date   Open   High    Low  Close    Volume  Name
# 0 2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 1 2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2 2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 3 2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 4 2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA

# %%
data.tail()
# Out:
#            Date   Open   High    Low  Close    Volume  Name
# 3014 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 3015 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 3016 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 3017 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 3018 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA

# %%
data.sort_index(inplace=True)
data
# Out:
#            Date   Open   High    Low  Close    Volume  Name
# 0    2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 1    2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2    2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 3    2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 4    2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA
# ...         ...    ...    ...    ...    ...       ...   ...
# 3014 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 3015 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 3016 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 3017 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 3018 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 7 columns]

# %%
data = data.fillna(method="ffill")
data
# Out:
# <ipython-input-14-6345023fe517>:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   data = data.fillna(method="ffill")
#            Date   Open   High    Low  Close    Volume  Name
# 0    2006-01-03  39.69  41.22  38.79  40.91  24232729  AABA
# 1    2006-01-04  41.22  41.90  40.77  40.97  20553479  AABA
# 2    2006-01-05  40.93  41.73  40.85  41.53  12829610  AABA
# 3    2006-01-06  42.88  43.57  42.80  43.21  29422828  AABA
# 4    2006-01-09  43.10  43.66  42.82  43.42  16268338  AABA
# ...         ...    ...    ...    ...    ...       ...   ...
# 3014 2017-12-22  71.42  71.87  71.22  71.58  10979165  AABA
# 3015 2017-12-26  70.94  71.39  69.63  69.86   8542802  AABA
# 3016 2017-12-27  69.77  70.49  69.69  70.06   6345124  AABA
# 3017 2017-12-28  70.12  70.32  69.51  69.82   7556877  AABA
# 3018 2017-12-29  69.79  70.13  69.43  69.85   6613070  AABA
#
# [3019 rows x 7 columns]

# %%
print(data.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Name'], dtype='object')

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(data['Close'])
# Out:
# (np.float64(0.9478981895596873),
#  np.float64(0.9936846299287978),
#  19,
#  2999,
#  {'1%': np.float64(-3.43253236279788),
#   '5%': np.float64(-2.86250422682754),
#   '10%': np.float64(-2.5672832833096195)},
#  np.float64(5660.836066212147))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

data[['Volume']] = scaler.fit_transform(data[['Volume']])

# %%
data
# Out:
#              Open   High    Low  Close    Volume  Name
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  0.051098  AABA
# 2006-01-04  41.22  41.90  40.77  40.97  0.042665  AABA
# 2006-01-05  40.93  41.73  40.85  41.53  0.024962  AABA
# 2006-01-06  42.88  43.57  42.80  43.21  0.062994  AABA
# 2006-01-09  43.10  43.66  42.82  43.42  0.032843  AABA
# ...           ...    ...    ...    ...       ...   ...
# 2017-12-22  71.42  71.87  71.22  71.58  0.020720  AABA
# 2017-12-26  70.94  71.39  69.63  69.86  0.015136  AABA
# 2017-12-27  69.77  70.49  69.69  70.06  0.010099  AABA
# 2017-12-28  70.12  70.32  69.51  69.82  0.012876  AABA
# 2017-12-29  69.79  70.13  69.43  69.85  0.010713  AABA
#
# [3019 rows x 6 columns]

# %%
data['month'] = data.index.month
data['day'] = data.index.day
data['weekday'] = data.index.weekday
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-99458323a16d> in <cell line: 0>()
# ----> 1 data['month'] = data.index.month
#       2 data['day'] = data.index.day
#       3 data['weekday'] = data.index.weekday
#
# AttributeError: 'RangeIndex' object has no attribute 'month'

# %%
data
# Out:
#              Open   High    Low  Close    Volume  Name  month  day  weekday
# Date
# 2006-01-03  39.69  41.22  38.79  40.91  0.051098  AABA      1    3        1
# 2006-01-04  41.22  41.90  40.77  40.97  0.042665  AABA      1    4        2
# 2006-01-05  40.93  41.73  40.85  41.53  0.024962  AABA      1    5        3
# 2006-01-06  42.88  43.57  42.80  43.21  0.062994  AABA      1    6        4
# 2006-01-09  43.10  43.66  42.82  43.42  0.032843  AABA      1    9        0
# ...           ...    ...    ...    ...       ...   ...    ...  ...      ...
# 2017-12-22  71.42  71.87  71.22  71.58  0.020720  AABA     12   22        4
# 2017-12-26  70.94  71.39  69.63  69.86  0.015136  AABA     12   26        1
# 2017-12-27  69.77  70.49  69.69  70.06  0.010099  AABA     12   27        2
# 2017-12-28  70.12  70.32  69.51  69.82  0.012876  AABA     12   28        3
# 2017-12-29  69.79  70.13  69.43  69.85  0.010713  AABA     12   29        4
#
# [3019 rows x 9 columns]
